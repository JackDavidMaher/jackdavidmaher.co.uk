# %%
import numpy as np
import matplotlib.pyplot as plt
#The following list being ugly is solely due to grammarly being fridgid with their API keys. PLZ let me have access :(
grammarlyScores = [[0.0,0.0,0.39,0.96],[0.0,0.0,0.39,0.96],[0.0,0.0,0.39,0.96],[0.0,0.0,0.39,0.96],[0.0,0.0,0.39,0.96],[0.1,0.0,0.43,0.95],[0.1,0.0,0.99,0.98],[0.1,0.0,0.36,0.98],[0.1,0.0,0.0,0.98],[0.1,0.0,0.36,0.96],[0.2,0.0,0.37,0.97],[0.2,0.0,0.67,0.97],[0.2,0.0,0.37,0.96],[0.2,0.0,0.54,0.98],[0.2,0.0,0.50,0.95],[0.3,0.0,0.40,0.98],[0.3,0.0,0.35,0.96],[0.3,0.0,0.62,0.95],[0.3,0.0,0.42,0.98],[0.3,0.0,0.38,0.98]] #temp,plagiarism,ai detector,writing quality
plt.scatter([score[0] for score in grammarlyScores], [score[2] for score in grammarlyScores])
plt.xlabel('Temperature Setting')
plt.ylabel('AI Detection Score')
plt.title('AI Detection Score vs Temperature Setting')
plt.xlim(0,1)
plt.ylim(0,1)
plt.grid(True)
plt.show()
plt.scatter([score[0] for score in grammarlyScores], [score[3] for score in grammarlyScores])
plt.xlabel('Temperature Setting')
plt.ylabel('Writing Quality Score')
plt.title('Writing Quality Score vs Temperature Setting')
plt.xlim(0,1)
plt.ylim(0.8,1)
plt.grid(True)
plt.show()
plt.scatter([score[0] for score in grammarlyScores], [score[1] for score in grammarlyScores])
plt.xlabel('Temperature Setting')
plt.ylabel('Plagiarism Score')
plt.title('Plagiarism Score vs Temperature Setting')
plt.xlim(0,1)
plt.ylim(0,1)
plt.grid(True)
plt.show()
